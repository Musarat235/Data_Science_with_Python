# %% [markdown]
# 1. Import Libraries

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# 2. Import Dataset

# %%
df = pd.read_csv ('Chilla_data2_for_plots.csv')

# %%
df.head()
# Out:
#    Gender  Location    Age Qualification_completed    field_of_study  \
# 0    Male  Pakistan  36-40                 Masters  Natural Sciences
# 1    Male  Pakistan  26-30               Bachelors             CS/IT
# 2    Male  Pakistan  31-35                 Masters       Enginnering
# 3  Female  Pakistan  31-35                 Masters             CS/IT
# 4  Female  Pakistan  26-30                 Masters       Enginnering
#
#          Purpose_for_chilla What are you? Blood group   \
# 0     to boost my skill set     Unemplyed           B+
# 1     to boost my skill set       Student           B+
# 2  Switch my field of study      Employed           B+
# 3     to boost my skill set      Employed           O+
# 4     to boost my skill set       Student           A-
#
#   Which mobile sim do you use Prepaid or Postpaid  ...  \
# 0                      U-fone             Prepaid  ...
# 1                      U-fone             Prepaid  ...
# ...

# %%
df.describe()
# Out:
#        Research/Working experience (Float/Int) years  Age (years)-Float/Int  \
# count                                     375.000000             375.000000
# mean                                        8.388800              27.576933
# std                                       104.337114               7.224460
# min                                         0.000000               0.000000
# 25%                                         0.100000              24.000000
# 50%                                         2.000000              27.000000
# 75%                                         4.000000              31.000000
# max                                      2022.000000              90.000000
#
#        Your Weight in kg? (float)  Height in cm? Freelancer- (Float)  \
# count                  375.000000                         375.000000
# mean                    69.321147                         162.679282
# std                     16.264434                         172.246844
# ...

# %%
sns.barplot(data=df, x='Gender', y='Age (years)-Float/Int', palette='flare',hue='Qualification_completed')
plt.show()

# %%
sns.catplot(data=df, x='How many hours you code a day? (int) e.g: 5,4,3', y='What are you?', kind = 'bar', palette='pastel',hue='Prepaid or Postpaid')
plt.show()

# %%
sns.lineplot(data=df, x='Where do you live?', y='Light kitni der band hti hy? int', palette='dark',hue='Location')
plt.show()

# %%
sns.boxenplot(data=df, x='Your Weight in kg? (float)', y='Your favorite programming language?')
plt.show()

# %%
sns.barplot(data=df, x='Your Weight in kg? (float)', y='Your favorite programming language?',
            linewidth=2.5, facecolor='lightblue',
            errcolor=".2", edgecolor="black")
plt.show()

# %%
sns.boxplot(data=df, x='Gender', y='Height in cm? Freelancer- (Float)',hue='Where do you live?',dodge=True, palette='Set2')
plt.show()

# %%
sns.boxplot(x=df['Your Weight in kg? (float)'])
plt.show()

# %%
# Set up a grid of axes with a polar projection
g = sns.FacetGrid(df, col="Where do you live?", hue="Where do you live?",
                  subplot_kws=dict(projection='polar'), height=4.5,
                  sharex=False, sharey=False, despine=False)

# Draw a scatterplot onto each axes in the grid
g.map(sns.scatterplot, "Age (years)-Float/Int", "What are you?")

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="whitegrid")

# Load the example diamonds dataset
diamonds = sns.load_dataset("diamonds")

# Draw a scatter plot while assigning point colors and sizes to different
# variables in the dataset
f, ax = plt.subplots(figsize=(6.5, 6.5))
sns.despine(f, left=True, bottom=True)
clarity_ranking = ["I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF"]
sns.scatterplot(x="carat", y="price",
                hue="clarity", size="depth",
                palette="ch:r=-.2,d=.3_r",
                hue_order=clarity_ranking,
                sizes=(1, 8), linewidth=0,
                data=diamonds, ax=ax)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.set_theme(style="darkgrid")
sns.displot(
    df, x="Age (years)-Float/Int", col="Marital Status?", row="Gender",
    binwidth=3, height=3, facet_kws=dict(margin_titles=True),
)

# %%
sns.pairplot(data=df, hue='Prepaid or Postpaid', palette='rocket_r')

# %%
# Plot sepal width as a function of sepal_length across days
g = sns.lmplot(
    data=df,
    x="How many hours you code a day? (int) e.g: 5,4,3", y="Light kitni der band hti hy? int", hue="Marital Status?",
    height=5
)

# Use more informative axis labels than are provided by default
g.set_axis_labels("Hour you code a day", "Light kitni der band hti hy? int")
